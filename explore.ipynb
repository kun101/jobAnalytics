# %%
import pandas as pd

# %%
# read data.csv
df = pd.read_csv('data.csv')
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
# drop 'SOAI', 'AISelect', 'AISent', 'AIAcc', 'AIBen',
    #    'AIToolInterested in Using', 'AIToolCurrently Using',
    #    'AIToolNot interested in Using', 'AINextVery different',
    #    'AINextNeither different nor similar', 'AINextSomewhat similar',
    #    'AINextVery similar', 'AINextSomewhat different', 'TBranch', 'ICorPM',
    #    'WorkExp', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
    #    'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8',
    #    'Frequency_1', 'Frequency_2', 'Frequency_3', 'TimeSearching',
    #    'TimeAnswering',
    
df = df.drop(['SOAI', 'AISelect', 'AISent', 'AIAcc', 'AIBen',
         'AIToolInterested in Using', 'AIToolCurrently Using',
            'AIToolNot interested in Using', 'AINextVery different',
            'AINextNeither different nor similar', 'AINextSomewhat similar',
            'AINextVery similar', 'AINextSomewhat different', 'TBranch', 'ICorPM',
            'WorkExp', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3', 'Knowledge_4',
            'Knowledge_5', 'Knowledge_6', 'Knowledge_7', 'Knowledge_8',
            'Frequency_1', 'Frequency_2', 'Frequency_3', 'TimeSearching',
            'TimeAnswering'], axis=1)

# %%
df.fillna("", inplace=True)
# keep only those rows which contain Employment substring "Employed"
df = df[df['Employment'].str.contains("Employed")]
# Out:
# C:\Users\kunal\AppData\Local\Temp\ipykernel_11668\3198145979.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("", inplace=True)

# %%
df.to_csv('employed.csv', index=False)

# %%
df[["TechList","ProfessionalTech"]]
# Out:
#            TechList  \
# 0               NaN
# 1       Investigate
# 2      Given a list
# 3       Investigate
# 4       Investigate
# ...             ...
# 89179   Investigate
# 89180   Investigate
# 89181           NaN
# 89182   Investigate
# 89183           NaN
#
#                                                                                                                                                                                                                   ProfessionalTech
# 0                                                                                                                                                                                                                              NaN
# 1                                                                                                                                                              DevOps function;Microservices;Automated testing;Observability tools
# ...

# %%
df.head(5)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
# 2           3  I agree  I am a developer by profession  45-54 years old
# 3           4  I agree  I am a developer by profession  25-34 years old
# 4           5  I agree  I am a developer by profession  25-34 years old
#
#                                                                  Employment  \
# 0                                                                       NaN
# 1                                                       Employed, full-time
# 2                                                       Employed, full-time
# 3                                                       Employed, full-time
# 4  Employed, full-time;Independent contractor, freelancer, or self-employed
#
#                              RemoteWork  \
# ...

# %%
# show all columns full data
pd.set_option('display.max_columns', None)
df.head(2)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 1  Employed, full-time     Remote
#
#                                                                                                                         CodingActivities  \
# 0                                                                                                                                    NaN
# 1  Hobby;Contribute to open-source projects;Bootstrapping a business;Professional development or self-paced learning from online courses
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
# ...

# %%
new_df = df[["Employment","CodingActivities","DevType","Country","LanguageHaveWorkedWith","DatabaseHaveWorkedWith","WebframeHaveWorkedWith","MiscTechHaveWorkedWith","ToolsTechHaveWorkedWith","NEWCollabToolsHaveWorkedWith"]]

# %%
# show only those rows where country is India
new_df[new_df["Country"] == "India"]
# Out:
#                                    Employment  \
# 9          Not employed, but looking for work
# 66                        Employed, full-time
# 78                        Employed, full-time
# 82                        Employed, full-time
# 85                        Employed, full-time
# ...                                       ...
# 89119  Student, full-time;Employed, part-time
# 89121  Employed, full-time;Student, part-time
# 89164                     Employed, full-time
# 89165                     Employed, full-time
# 89167                     Employed, full-time
#
#                                                                                                                            CodingActivities  \
# 9                                                                                                                                       NaN
# ...

# %%
# replace NaNs in HaveWorkedWith columns with empty string
new_df.fillna("", inplace=True)

# concatenate all HaveWorkedWith columns into one column
new_df["skills"] = new_df["LanguageHaveWorkedWith"] + new_df["DatabaseHaveWorkedWith"] + new_df["WebframeHaveWorkedWith"] + new_df["MiscTechHaveWorkedWith"] + new_df["ToolsTechHaveWorkedWith"] + new_df["NEWCollabToolsHaveWorkedWith"]
# Out:
# C:\Users\kunal\AppData\Local\Temp\ipykernel_12056\987206412.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.fillna("", inplace=True)
# C:\Users\kunal\AppData\Local\Temp\ipykernel_12056\987206412.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["skills"] = new_df["LanguageHaveWorkedWith"] + new_df["DatabaseHaveWorkedWith"] + new_df["WebframeHaveWorkedWith"] + new_df["MiscTechHaveWorkedWith"] + new_df["ToolsTechHaveWorkedWith"] + new_df["NEWCollabToolsHaveWorkedWith"]

# %%
# dont truncate the skills column
pd.set_option('display.max_colwidth', None)
new_df
# Out:
#                                                                      Employment  \
# 0
# 1                                                           Employed, full-time
# 2                                                           Employed, full-time
# 3                                                           Employed, full-time
# 4      Employed, full-time;Independent contractor, freelancer, or self-employed
# ...                                                                         ...
# 89179  Employed, full-time;Independent contractor, freelancer, or self-employed
# 89180                                    Student, full-time;Employed, part-time
# 89181                                                       I prefer not to say
# 89182                                    Employed, part-time;Student, part-time
# 89183                                                       Employed, full-time
#
# ...

# %%
# split the skills column into a list of skills
new_df["skills"] = new_df["skills"].str.split(";")
new_df
# Out:
# C:\Users\kunal\AppData\Local\Temp\ipykernel_12056\3265793246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df["skills"] = new_df["skills"].str.split(";")
#                                                                      Employment  \
# 0
# 1                                                           Employed, full-time
# 2                                                           Employed, full-time
# 3                                                           Employed, full-time
# 4      Employed, full-time;Independent contractor, freelancer, or self-employed
# ...                                                                         ...
# 89179  Employed, full-time;Independent contractor, freelancer, or self-employed
# ...
